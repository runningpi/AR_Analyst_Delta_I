# %% [markdown]
# # Example Reports

# %%
# Testdateien für die Pilotanalyse
pilot_analyse_dateien = [
    # Primärquellen (Earnings Call)
    '01_31_2023__LSEG_StreetEvents__AMD_OQ_-_Event_Brief_of_Advanced_Micro_Devices_Inc_conference_call__Jan__31__2023___5_00PM_ET__Research_Department.pdf',
    '01_31_2023__LSEG_StreetEvents__AMD_OQ_-_Event_Transcript_of_Advanced_Micro_Devices_Inc_conference_call__Jan__31__2023___5_00PM_ET__Research_Department.pdf',
    
    # Nachfolgende Analysten-Reports
    '02_01_2023__Invest_Heroes__AMD___________________________4_____2022_______Dmitrii_Novichkov.pdf', # auf russisch?
    '02_01_2023__Rosenblatt_Securities__Inc___ABC_News__AI__Bandwidth_and_Compute_in_the_Last_Week__Mr__Hans_Mosesmann.pdf', # viel Text, gut geeignet
    '02_03_2023__Invest_Heroes__AMD__financial_results_for_Q4_2022__Dmitrii_Novichkov.pdf', # englische Version zum russischen
    '02_06_2023__Marktfeld__Advanced_Micro_Devices_Inc__Peer_Group_Analytics_-_Q4_FY2022__Michail_Paraskevopoulos.pdf', # nur Graphen über verschiedene Metriken
    '02_09_2023__PriceTarget_Research__Advanced_Micro_Devices_Inc_Investment_Status_Report__John_Lafferty.pdf' # Graphen und Text, vielleicht geeignet
]

# %% [markdown]
# # Information extraction from Rosenblatt_Securities Text

# %%
import os, json, time, asyncio
from dotenv import load_dotenv
from openai import AsyncOpenAI
from tqdm import tqdm

# ----------------- Setup -----------------
load_dotenv()
client = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))

MAX_CONCURRENT = 10  # Anzahl paralleler Anfragen

system_prompt = """
You are an expert financial text cleaner and extractor.

Your task:
1. Split the provided input into single sentences.
   - For each: save clean "text", the exact "quote" (original snippet), classify as Statement, Evaluation, Forecast (multiple possible).
   - Add "source": "text".
2. Detect tables in the input.
   - For each key/value row: treat as one entry.
   - Save "text" as "Key: Value".
   - Save "quote" as the original row text.
   - Classify as Statement, Evaluation, Forecast.
   - Add "source": "table".
   - If value is a range or number, keep it as is in "text" (do not parse separately).
   - Add the header of the paragraph where the quote comes from.
3. If there is other structured content (e.g. headings, lists, metadata), include them as entries with "source": "other".
4. Output JSON only in this format:

{
  "items": [
    {
      "text": "...",
      "quote": "...",
      "types": ["Statement","Evaluation", "Forecast"],
      "source": "text|table|other",
      "paragraph": "header of the paragraph"
    }
  ]
}
"""

# ----------------- GPT Call -----------------
async def extract_with_gpt(text: str) -> dict:
    resp = await client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": system_prompt.strip()},
            {"role": "user", "content": text}
        ],
        response_format={"type": "json_object"}
    )
    return json.loads(resp.choices[0].message.content)

# ----------------- Single Chunk -----------------
async def process_chunk(chunk, sem, pbar):
    cid = chunk.get("chunk_id")
    page = chunk.get("page_number")
    content = chunk.get("content", "")

    if not content:
        pbar.update(1)
        return []

    async with sem:  # Rate-Limiting
        try:
            extracted = await extract_with_gpt(content)
            out = []
            for item in extracted.get("items", []):
                item["chunk_id"] = cid
                item["page"] = page
                out.append(item)
        except Exception as e:
            out = [{
                "chunk_id": cid,
                "page": page,
                "error": str(e)
            }]
        finally:
            pbar.update(1)
        return out

# ----------------- Main -----------------
async def process_chunks_file_parallel(input_path: str, output_path: str):
    with open(input_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    chunks = data.get("chunks", [])
    results = {
        "source_file": data.get("document_info", {}).get("filename"),
        "processed_at": time.strftime("%Y-%m-%dT%H:%M:%S"),
        "model": "gpt-5-nano",
        "items": []
    }

    sem = asyncio.Semaphore(MAX_CONCURRENT)
    pbar = tqdm(total=len(chunks), desc="Processing", unit="chunk")

    tasks = [process_chunk(ch, sem, pbar) for ch in chunks]
    all_results = await asyncio.gather(*tasks, return_exceptions=True)

    pbar.close()

    for res in all_results:
        if isinstance(res, list):
            results["items"].extend(res)
        elif isinstance(res, Exception):
            results["items"].append({"error": str(res)})

    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

    print(f"✅ Done: {output_path}")

# ----------------- Run -----------------
if __name__ == "__main__":
    input_path = "../mistral_OCR/02_01_2023__Rosenblatt_Securities__Inc___ABC_News__AI__Bandwidth_and_Compute_in_the_Last_Week__Mr__Hans_Mosesmann_ocr_chunks.json"
    output_path = "02_01_2023__Rosenblatt_Securities__Inc___ABC_News__AI__Bandwidth_and_Compute_in_the_Last_Week__Mr__Hans_Mosesmann_extracted.json"
    await process_chunks_file_parallel(input_path, output_path)
# Out:
# Processing: 100%|██████████| 21/21 [02:42<00:00,  7.76s/chunk]
# ✅ Done: 02_01_2023__Rosenblatt_Securities__Inc___ABC_News__AI__Bandwidth_and_Compute_in_the_Last_Week__Mr__Hans_Mosesmann_extracted.json

# %% [markdown]
# # DSRAG Pipeline

# %%
# !pip install dsrag
# Out:
# Requirement already satisfied: dsrag in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (0.5.5)
# Requirement already satisfied: langchain-text-splitters>=0.3.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (0.3.11)
# Requirement already satisfied: langchain-core>=0.3.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (0.3.76)
# Requirement already satisfied: pydantic>=2.8.2 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (2.10.3)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (2.1.3)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (2.2.3)
# Requirement already satisfied: tiktoken>=0.5.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (0.11.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (4.67.1)
# Requirement already satisfied: requests>=2.30.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (2.32.3)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (4.12.2)
# Requirement already satisfied: instructor>=1.7.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (1.11.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (1.6.1)
# Requirement already satisfied: pillow>=10.0.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (11.1.0)
# Requirement already satisfied: pdf2image>=1.16.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (1.17.0)
# Requirement already satisfied: docx2txt>=0.8 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (0.9)
# Requirement already satisfied: pypdf>=3.0.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from dsrag) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (3.11.10)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (3.1.6)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (0.10.0)
# Requirement already satisfied: openai<2.0.0,>=1.70.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (1.107.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (2.27.1)
# Requirement already satisfied: rich<15.0.0,>=13.7.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (13.9.4)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (9.0.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from instructor>=1.7.0->dsrag) (0.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.7.0->dsrag) (1.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.7.0->dsrag) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (3.7)
# Requirement already satisfied: certifi in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor>=1.7.0->dsrag) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from pydantic>=2.8.2->dsrag) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from requests>=2.30.0->dsrag) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from requests>=2.30.0->dsrag) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from rich<15.0.0,>=13.7.0->instructor>=1.7.0->dsrag) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from rich<15.0.0,>=13.7.0->instructor>=1.7.0->dsrag) (2.19.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from typer<1.0.0,>=0.9.0->instructor>=1.7.0->dsrag) (7.1.2)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langchain-core>=0.3.0->dsrag) (0.4.29)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langchain-core>=0.3.0->dsrag) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langchain-core>=0.3.0->dsrag) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langchain-core>=0.3.0->dsrag) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.3.0->dsrag) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.3.0->dsrag) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.3.0->dsrag) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.3.0->dsrag) (0.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor>=1.7.0->dsrag) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from pandas>=2.0.0->dsrag) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from pandas>=2.0.0->dsrag) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from pandas>=2.0.0->dsrag) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->dsrag) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->dsrag) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->dsrag) (3.5.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from tiktoken>=0.5.0->dsrag) (2024.11.6)
# Requirement already satisfied: colorama in c:\users\maalthau\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.65.0->dsrag) (0.4.6)

# %%
from dsrag.llm import OpenAIChatAPI
from dsrag.reranker import CohereReranker
from dsrag.create_kb import create_kb_from_file
from dsrag.knowledge_base import KnowledgeBase
from dotenv import load_dotenv
load_dotenv()

from dsrag.knowledge_base import KnowledgeBase

llm = OpenAIChatAPI(model='gpt-4o-mini')
reranker = CohereReranker()

kb = KnowledgeBase(kb_id="AMD_Jan_2023_Earnings_Call", reranker=reranker, auto_context_model=llm, storage_directory="./my_kb_storage")

# %%
print(kb.storage_directory)
# Out:
# ./my_kb_storage

# %%
kb.add_document(
    doc_id="2022 10-Q-3Q22.pdf",
    file_path="assets/2022 10-Q-3Q22.pdf",
    chunk_size=200,
    semantic_sectioning_config={"use_semantic_sectioning": False}
)

kb.add_document(
    doc_id="2022 10-Q-anual.pdf",
    file_path="assets/2022 10-Q-anual.pdf",
    chunk_size=200,
    semantic_sectioning_config={"use_semantic_sectioning": False}
)

kb.add_document(
    doc_id="2022 Q4 - 8-K.pdf",
    file_path="assets/2022 Q4 - 8-K.pdf",
    chunk_size=200,
    semantic_sectioning_config={"use_semantic_sectioning": False}
)

kb.add_document(
    doc_id="2022 Q4 - Presentation.pdf",
    file_path="assets/2022 Q4 - Presentation.pdf",
    chunk_size=200,
    semantic_sectioning_config={"use_semantic_sectioning": False}
)

kb.add_document(
    doc_id="01_31_2023_LSEG_Brief.pdf",
    file_path="assets/01_31_2023_LSEG_Brief.pdf",
    chunk_size=200,
    semantic_sectioning_config={"use_semantic_sectioning": False}
)

kb.add_document(
    doc_id="01_32_2023_LSEG_Transcript.pdf",
    file_path="assets/01_32_2023_LSEG_Transcript.pdf",
    chunk_size=200,
    semantic_sectioning_config={"use_semantic_sectioning": False}
)

# %%
import json
from tqdm import tqdm
from dsrag.knowledge_base import KnowledgeBase

# JSON einlesen
with open("02_01_2023_Rosenblatt_Export.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Die ersten 10 Sätze aus items holen
sentences = [
    item.get("text", item.get("quote", "")) 
    for item in data["items"]
]
# nur nicht-leere Strings
sentences = [s for s in sentences if s]
# Dict für Anfragen + Ergebnisse
query_results = {}

# Jede Anfrage ausführen und Ergebnisse speichern
for i, sentence in enumerate(tqdm(sentences, desc="Querying", unit="sent"), start=1):
    results = kb.query([sentence])
    query_results[f"sentence_{i}"] = {
        "query": sentence,
        "results": [str(segment) for segment in results]
    }

# Optional: JSON speichern
with open("query_results.json", "w", encoding="utf-8") as f:
    json.dump(query_results, f, ensure_ascii=False, indent=2)

print("Fertig, Ergebnisse in query_results.json gespeichert.")
# Out:
# Querying: 100%|██████████| 294/294 [04:32<00:00,  1.08sent/s]
# Fertig, Ergebnisse in query_results.json gespeichert.

# %% [markdown]
# # LLM Analysis

# %%
import json
import ast
import re
from openai import OpenAI

client = OpenAI()

qr_path = "query_results.json"
with open(qr_path, "r", encoding="utf-8") as f:
    query_results = json.load(f)

def parse_result_str(s: str) -> dict:
    s = re.sub(r"np\.float64\(([^)]+)\)", r"\1", s)
    return ast.literal_eval(s)

def segment_to_text(seg: dict) -> str:
    for k in ("content", "text", "body"):
        if k in seg and isinstance(seg[k], str):
            return seg[k]
    return json.dumps(seg, ensure_ascii=False)

system_prompt = """You are an expert financial analyst.
Evaluate whether the provided Knowledge Base evidence supports the snippet.
Return a JSON object with two keys:
- evaluation: one of [Supported, Partially Supported, Not Supported, Contradicted, No Evidence]
- reason: a short explanation.
"""

evaluations = {}

for key in list(query_results.keys()):  # nur 5 Elemente
    entry = query_results[key]
    quote = entry.get("query", "")
    raw_results = entry.get("results", [])[:5]

    if not raw_results:
        evaluations[key] = {
            "query": quote,
            "evaluation": "No Evidence",
            "reason": "Keine Evidenz gefunden",
            "evidence": []
        }
        print(f"\n{key}: {quote}\n → Keine Evidenz gefunden")
        continue

    parsed = []
    for r in raw_results:
        try:
            parsed.append(parse_result_str(r))
        except Exception:
            parsed.append({"text": str(r)})

    ev_texts = [segment_to_text(seg) for seg in parsed]
    evidence_combined = "\n---\n".join(ev_texts)

    user_prompt = f"""Snippet:
{quote}

Evidence from Knowledge Base:
{evidence_combined}
"""

    resp = client.chat.completions.create(
        model="gpt-5-nano",
        response_format={"type": "json_object"},  # garantiert JSON
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ]
    )

    parsed_eval = json.loads(resp.choices[0].message.content)

    evaluations[key] = {
        "query": quote,
        "evidence": ev_texts,
        "evaluation": parsed_eval.get("evaluation", "Unknown"),
        "reason": parsed_eval.get("reason", "")
    }

    print(f"\n{key}: {quote}")
    print(" → Label:", evaluations[key]["evaluation"])
    print(" → Reason:", evaluations[key]["reason"])

# JSON mit Bewertungen speichern
with open("evaluations.json", "w", encoding="utf-8") as f:
    json.dump(evaluations, f, ensure_ascii=False, indent=2)

print("\nFertig, Bewertungen in evaluations.json gespeichert")
# Out:
# sentence_1: Advanced Micro Devices is the number-two player in x86-based microprocessors, behind Intel, and -- with the 2008 acquisition of ATI -- a top player in graphic processors.
#  → Label: Not Supported
#  → Reason: The knowledge base states Intel has been the market share leader for microprocessors but does not specify AMD's ranking (second) or reference the 2008 ATI acquisition or AMD's position in graphics processors. Therefore, the snippet's claims are not supported by the provided KB.
#
# sentence_2: In 2021, Advanced Micro Devices acquired Xilinx, expanding its presence in embedded computing and data center.
#  → Label: Contradicted
#  → Reason: Knowledge Base states the Xilinx acquisition was completed on February 14, 2022 (not 2021), though it confirms expansion into embedded computing and data center segments via the acquired Xilinx portfolio.
#
# sentence_3: Analyst's Notes
#  → Keine Evidenz gefunden
#
# sentence_4: Analysis by Jim Kelleher, CFA, February 1, 2023
#  → Keine Evidenz gefunden
#
# sentence_5: ARGUS RATING: BUY - PC weakness, data center strength, caution ahead
#  → Keine Evidenz gefunden
#
# sentence_6: - Advanced Micro Devices posted 4Q22 non-GAAP results that exceeded guidance and consensus estimates.
#  → Label: Not Supported
#  → Reason: The Knowledge Base includes 4Q22 non-GAAP metrics and references strong performance, but it does not contain any explicit statement that 4Q22 non-GAAP results exceeded guidance or consensus estimates.
#
# sentence_7: - Total revenue was up 16% despite weak client (PC) demand.
#  → Label: Supported
#  → Reason: KB states total revenue rose 16% year-over-year, driven by Embedded and Data Center, with lower revenue in the Client (PC) segment and Gaming. This matches the snippet's claim that total revenue was up 16% despite weak client (PC) demand, since the client/PC weakness is noted as offsetting part of the growth.
#
# sentence_8: - AMD posted a 16% annual decline in non-GAAP EPS for 4Q22, following 3Q22 results that included its first negative EPS comp since 2Q19.
#  → Label: Contradicted
#  → Reason: KB shows Q4'22 Non-GAAP EPS declined 25% year-over-year (0.69 vs 0.92), not 16%. The KB does not confirm the 3Q22 claim about first negative EPS comp since 2Q19, leaving that part unverified.
#
# sentence_9: - AMD's client (PC) segment sales in 4Q22 were half the level of 4Q21 sales.
#  → Label: Supported
#  → Reason: Q4'22 Client Net Revenue was $903M vs Q4'21 $1,829M (down ~51%), i.e., about half, which supports the claim that 4Q22 PC segment sales were roughly half of 4Q21.
#
# sentence_10: - Worldwide PC unit sales declined 29% in 4Q22 on top of a 15% decline in 3Q22.
#  → Keine Evidenz gefunden
#
# sentence_11: - AMD's cautious 1Q23 guidance on revenue (down 10% year-over-year) reflects the challenging environment.
#  → Label: Supported
#  → Reason: The knowledge base includes AMD's Q1’23 guidance: expected revenue around $5.3 billion +/- $0.3B, a ~10% YoY decrease, with notes that demand environment is challenging and that the outlook is cautious until demand improves, aligning with the snippet.
#
# sentence_12: Demand will likely remain weak into early 2023, although we look for sequential recovery as the year progresses.
#  → Keine Evidenz gefunden
#
# sentence_13: BUY-rated Advanced Micro Devices Inc. (NGS: AMD) rose 7% in a down market on 2/1/23 after the company delivered results that exceeded 4Q22 guidance.
#  → Label: Not Supported
#  → Reason: The Knowledge Base includes AMD's Q4 2022 results and full-year data but has no information about a 2/1/23 stock move, a 'BUY' rating, or beating 4Q22 guidance. Therefore it does not substantiate the snippet.
#
# sentence_14: AMD posted 4Q22 revenue growth of 16%, while non-GAAP EPS fell 25%.
#  → Label: Supported
#  → Reason: KB shows Q4’22 revenue up 16% YoY and Non-GAAP EPS down 25% (0.69 vs 0.92), which matches the snippet's statements.
#
# sentence_15: AMD's client (PC) segment sales in 4Q22 were half the level of 4Q21 sales.
#  → Label: Supported
#  → Reason: Q4'22 Client Net Revenue was $903M vs $1,829M in Q4'21, down 51% (roughly 49% of the prior quarter), i.e., about half the level.
#
# sentence_16: For context, worldwide PC sales declined 29% in 4Q22 on top of a 15% decline in 3Q22.
#  → Label: No Evidence
#  → Reason: The KB excerpt reports AMD's 4Q22 revenue growth driven by Embedded and Data Center segments and does not mention worldwide PC sales or any declines, so it provides no evidence for the snippet about PC market declines.
#
# sentence_17: PC demand will likely remain weak into early 2023, although we look for sequential recovery as the year progresses.
#  → Label: Supported
#  → Reason: KB notes PC demand remains soft with an expected mixed demand environment in 2023 and 2H23 stronger than 1H23, plus an approximate 10% drop in PC TAM for 2023, which aligns with weak early 2023 demand and sequential recovery later in the year.
#
# sentence_18: AMD's cautious 1Q23 revenue growth and gross margin guidance forecast reflects the challenging environment.
#  → Label: Supported
#  → Reason: The KB indicates Q1’23 revenue is guided to be around $5.3B with a ~10% year-over-year decrease (i.e., cautious/restrained growth) and that gross margin is expected near 50%, with 1Q23–1H23 margins flat and potential expansion in 2H23. It also notes a challenging demand environment with improvement anticipated later, which aligns with the snippet’s claim.
#
# sentence_19: Gaming-related sales declined year over year, reflecting both inflationary pressure on
#  → Label: Partially Supported
#  → Reason: The KB confirms a 7% YoY decline in Gaming revenue driven by lower gaming graphics sales, aligning with 'gaming-related sales declined year over year.' However, the specific claim about 'inflationary pressure on' something is not explicitly evidenced in the provided excerpt (the sentence is truncated), so that part is not supported.
#
# sentence_20: Valuation
#  → Keine Evidenz gefunden
#
# sentence_21: Target Price: $100.00
#  → Keine Evidenz gefunden
#
# sentence_22: 52 Week Price Range: $54.57 to $132.96
#  → Keine Evidenz gefunden
#
# sentence_23: Shares Outstanding: 1.61 Billion
#  → Keine Evidenz gefunden
#
# sentence_24: Dividend: $0.00
#  → Keine Evidenz gefunden
#
# sentence_25: Sector Overview: Sector Technology
#  → Keine Evidenz gefunden
#
# sentence_26: Sector Rating: MARKET WEIGHT
#  → Keine Evidenz gefunden
#
# sentence_27: Total % of S&P 500 Market Cap.: 25.00%
#  → Keine Evidenz gefunden
#
# sentence_28: Financial Strength: MEDIUM-HIGH
#  → Keine Evidenz gefunden
#
# sentence_29: Debt/Capital Ratio: 8.9%
#  → Keine Evidenz gefunden
#
# sentence_30: Return on Equity: 10.7%
#  → Keine Evidenz gefunden
#
# sentence_31: Net Margin: 5.6%
#  → Keine Evidenz gefunden
#
# sentence_32: Payout Ratio: -
#  → Keine Evidenz gefunden
#
# sentence_33: Current Ratio: 2.02
#  → Keine Evidenz gefunden
#
# sentence_34: Revenue: 23.60 Billion
#  → Label: Supported
#  → Reason: The KB document states AMD FY2022 revenue of $23.6 billion, which matches the snippet value 'Revenue: 23.60 Billion'.
#
# sentence_35: After-Tax Income: 1.32 Billion
#  → Keine Evidenz gefunden
#
# sentence_36: Current FY P/E: 21.53
#  → Keine Evidenz gefunden
#
# sentence_37: Prior FY P/E: 21.78
#  → Keine Evidenz gefunden
#
# sentence_38: Price/Sales: 5.13
#  → Keine Evidenz gefunden
#
# sentence_39: Price/Book: 2.22
#  → Keine Evidenz gefunden
#
# sentence_40: Book Value/Share: 33.83
#  → Keine Evidenz gefunden
#
# sentence_41: Market Capitalization: 121.17 Billion
#  → Keine Evidenz gefunden
#
# sentence_42: Forecasted Growth: 1 Year EPS Growth Forecast 1.16%, 5 Year EPS Growth Forecast 10.00%, 1 Year Dividend Growth Forecast N/A
#  → Keine Evidenz gefunden
#
# sentence_43: Risk Beta: 1.55
#  → Keine Evidenz gefunden
#
# sentence_44: Institutional Ownership: 67.88%
#  → Keine Evidenz gefunden
#
# sentence_45: Continued multi-year gains in market share.
#  → Keine Evidenz gefunden
#
# sentence_46: The early 2023 growth outlook is uncertain.
#  → Label: Supported
#  → Reason: The KB states that AMD's forward-looking outlook statements are based on current expectations as of Jan 31, 2023 and involve numerous risks and uncertainties, implying that the early-2023 growth outlook is uncertain.
#
# sentence_47: But share gains in client and in data center, market leadership in console gaming, and the much enhanced embedded business position AMD for long-term growth exceeding those of the market and the peer group.
#  → Keine Evidenz gefunden
#
# sentence_48: AMD has announced that long-time finance industry professional Jean Hu is joining the company as CFO.
#  → Label: Supported
#  → Reason: Knowledge Base documents reference Jean X. Hu as the new Executive VP & CFO of AMD and note she joined the company earlier this month, confirming she is joining as CFO and aligning with the snippet.
#
# sentence_49: She replaces Devinder Kumar, who is retiring.
#  → Label: Supported
#  → Reason: KB shows Devinder Kumar steps down as CFO and Jean Hu is appointed as the new CFO, implying replacement due to retirement after a long tenure.
#
# sentence_50: CFO.
#  → Keine Evidenz gefunden
#
# sentence_51: Hu has served in the CFO role (and at times as interim CEO) at QLogic, Conexant, and Marvell, along with other postings.
#  → Keine Evidenz gefunden
#
# sentence_52: She is well-respected in financial circles, and we believe she will benefit the already strong leadership team at AMD.
#  → Label: Partially Supported
#  → Reason: KB states she has public company CFO experience and a proven track record, and that she is an excellent addition to the team. It does not explicitly say she is 'well-respected in financial circles' or that she will benefit an 'already strong leadership team at AMD'.
#
# sentence_53: In our view, the share price does not fully reflect AMD's long-term revenue and margin growth potential, along with ongoing market share gains at Intel's expense.
#  → Keine Evidenz gefunden
#
# sentence_54: We are reiterating our BUY rating and 12-month target price of $100.
#  → Keine Evidenz gefunden
#
# sentence_55: ## RECENT DEVELOPMENTS
#  → Keine Evidenz gefunden
#
# sentence_56: AMD is up $16% year-to-date in 2023, while the peer group is up $15%.
#  → Label: No Evidence
#  → Reason: The knowledge base excerpts describe AMD's Q4/FY2022 financial results and do not provide any information about AMD's or its peers' stock price performance in 2023 or year-to-date performance.
#
# sentence_57: AMD declined $55% in 2022, while the Argus semiconductor peer group fell $36%.
#  → Label: No Evidence
#  → Reason: The Knowledge Base covers AMD's 2022 financial results but does not mention stock price performance or Argus semiconductor peer group performance, so the claim about a 55% decline and a 36% peer decline is not supported.
#
# sentence_58: AMD advanced $57% in 2021, versus a $34%$ gain for peer group;
#  → Label: No Evidence
#  → Reason: The Knowledge Base excerpt provides AMD's 2022 vs 2021 revenue and gross profit figures but contains no information about a 57% advance in 2021 or a 34% gain for peers. Therefore the snippet is not supported (and not contradicted) by the KB.
#
# sentence_59: rose $100%$ in 2020, while peers advanced $49%$;
#  → Keine Evidenz gefunden
#
# sentence_60: was up $148%$ in 2019, while peers were up $54%$; and rose $80%$ in 2018, compared with a $4%$ decline for peers.
#  → Keine Evidenz gefunden
#
# sentence_61: AMD, which has been as high as $154 late in 2021, was a sub-$2 stock in 2015.
#  → Keine Evidenz gefunden
#
# sentence_62: For 4Q22, Advanced Micro Devices reported revenue of $6.0 billion, which was up $16% year-over-year and $1% sequentially.
#  → Label: Partially Supported
#  → Reason: KB shows 4Q22 revenue as $5.6B with 16% YoY growth, not $6.0B. It does not provide evidence of a 1% sequential increase. Therefore the YoY figure is supported, but the revenue amount and the sequential growth claim are not fully supported.
#
# sentence_63: Revenue included a full contribution from Xilinx.
#  → Label: Supported
#  → Reason: KB states that 2022 revenue includes Xilinx revenue for the full twelve months following the February 2022 acquisition, and that embedded revenue growth was driven by the inclusion of Xilinx, indicating a full contribution from Xilinx in the reported revenue.
#
# sentence_64: Revenue exceeded the high
#  → Keine Evidenz gefunden
#
# sentence_65: end of the guidance range of $5.2-$5.8 billion and was nearly half a billion dollars above the consensus estimate of $5.5 billion.
#  → Keine Evidenz gefunden
#
# sentence_66: Non-GAAP profit totaled $0.69 per diluted share, down 25% from $0.92 a year earlier and up $0.01 sequentially.
#  → Label: Partially Supported
#  → Reason: Evidence confirms Non-GAAP diluted EPS of $0.69 and a year-over-year decline from $0.92 (down 25%). However, the KB does not provide explicit evidence of a $0.01 sequential increase.
#
# sentence_67: AMD management does not provide explicit EPS guidance.
#  → Keine Evidenz gefunden
#
# sentence_68: The Street had projected non-GAAP EPS of $0.67.
#  → Keine Evidenz gefunden
#
# sentence_69: As of mid-year 2022, AMD had delivered a long string of record quarters, powering through the pandemic and the supply chain crisis while taking share in multiple end-markets.
#  → Label: Partially Supported
#  → Reason: The KB shows AMD had record revenue and strong growth in 2022 and references expansion in data center (including Xilinx) and market conditions (pandemic context). However, it does not explicitly confirm a 'long string of record quarters' by mid-2022 or explicitly state taking share across multiple end-markets in that period. Evidence supports some aspects (record performance, pandemic context, market share in at least one segment) but not the exact phrasing.
#
# sentence_70: The acquisition of Xilinx appeared to position AMD to build on existing strength and growing presence in data center markets.
#  → Label: Supported
#  → Reason: KB explicitly states that the Xilinx acquisition accelerated AMD's data center momentum, diversified the business, and strengthened its financial model, and mentions confidence in gaining market share in data center and delivering long-term growth, with data center revenue growth supporting the claim.
#
# sentence_71: The emergence of inflation at 40-year highs has changed global consumer spending patterns and has had a particularly intense impact in the consumer electronics space.
#  → Keine Evidenz gefunden
#
# sentence_72: For many companies, consumer weakness has spilled into the enterprise, carrier, and cloud data-center end markets.
#  → Keine Evidenz gefunden
#
# sentence_73: Fueled by the Xilinx acquisition and its own competitive share gains, AMD was able to offset some of the most intense weakness in the client space with strong product sales in data center and embedded processing.
#  → Label: Supported
#  → Reason: KB shows the Xilinx acquisition boosting Embedded revenue and data center momentum, while Client revenue weakened due to a weak PC market. This aligns with the snippet’s claim that data center and embedded processing offset the client-space weakness, and there are references to market-share momentum from leadership.
#
# sentence_74: CEO Lisa Su began by thanking former CFO Devinder Kumar for a remarkable 39 years at AMD, and welcoming incoming CFO Jean Hu.
#  → Label: Partially Supported
#  → Reason: KB confirms thanking Devinder Kumar for 39 years and welcoming Jean Hu during the CFO transition, which aligns with the snippet. However, the KB does not explicitly identify the speaker as CEO Lisa Su, so the attribution to her is not directly evidenced.
#
# sentence_75: Over the past 14 years, she has served in the CFO role (and at times as interim CEO) at QLogic, Conexant, and Marvell.
#  → Keine Evidenz gefunden
#
# sentence_76: Growth & Valuation Analysis
#  → Keine Evidenz gefunden
#
# sentence_77: GROWTH ANALYSIS | ($ in Millions, except per share data) | 2017 | 2018 | 2019 | 2020 | 2021 | | :--: | :--: | :--: | :--: | :--: | :--: | | Revenue | 5,253 | 6,475 | 6,731 | 9,763 | 16,434 | | COGS | 3,466 | 4,028 | 3,863 | 5,416 | 8,505
#  → Keine Evidenz gefunden
#
# sentence_78: Revenue: 5,253 | 6,475 | 6,731 | 9,763 | 16,434
#  → Label: Partially Supported
#  → Reason: The KB contains AMD net revenue figures including 9,763 and 16,434, which appear in the snippet, but the exact sequence 5,253 | 6,475 | 6,731 | 9,763 | 16,434 is not present in the KB, and several listed values are not corroborated by the provided evidence.
#
# sentence_79: COGS: 3,466 | 4,028 | 3,863 | 5,416 | 8,505
#  → Label: Not Supported
#  → Reason: The Knowledge Base provides three-year Cost of Sales values of 11,550, 8,505, 5,416 and Total Cost of Sales 12,998, 8,505, 5,416, plus Net Revenue figures, but it does not contain the sequence 3,466 | 4,028 | 3,863 | 5,416 | 8,505. Therefore the snippet cannot be supported by the KB evidence.
#
# sentence_80: Gross Profit: 1,787 | 2,447 | 2,868 | 4,347 | 7,929
#  → Label: Not Supported
#  → Reason: The knowledge base includes AMD gross profit figures (e.g., 7,929 as annual GAAP gross profit) but does not contain the exact sequence 1,787 | 2,447 | 2,868 | 4,347 | 7,929. Only one value matches; the rest are not present in the KB.
#
# sentence_81: SG&A: 516 | 562 | 750 | 995 | 1,448
#  → Keine Evidenz gefunden
#
# sentence_82: R&D: 1,196 | 1,434 | 1,547 | 1,983 | 2,845
#  → Label: Partially Supported
#  → Reason: The KB includes R&D figures that match two of the snippet values (1,983 and 2,845) but does not show the full five-number sequence (1,196; 1,434; 1,547) in the provided excerpts.
#
# sentence_83: Operating Income: 127 | 451 | 631 | 1,369 | 3,648
#  → Label: Partially Supported
#  → Reason: The KB confirms operating income values including 1,369 and 3,648 (e.g., 'Total operating income (loss) $ 1,264 $ 3,648 $ 1,369' and 'Operating income (loss)  (149) 1,207 1,264 3,648'). However, the specific preceding figures 127, 451, and 631 are not present in the excerpts, so the full five-number sequence is not fully supported by the provided evidence.
#
# sentence_84: Interest Expense: 120 | 103 | 79 | 39 | 26
#  → Keine Evidenz gefunden
#
# sentence_85: Pretax Income: $-8$ | 330 | 372 | 1,275 | 3,669
#  → Label: Partially Supported
#  → Reason: The KB discusses pretax income in AMD's 2022 Form 10-K and includes figures close to the snippet's later values (e.g., ~1,280 and ~3,675). However, the exact numbers and formatting in the snippet are not directly evidenced, and the snippet includes a negative value not shown in the KB excerpt. Therefore, partial support at best.
#
# sentence_86: Income Taxes: 18 | $-9$ | 31 | $-1,210$ | 513
#  → Label: Partially Supported
#  → Reason: The KB contains 'Income tax provision (benefit) $ (122) $ 513 $ (1,210)' for 2022-2020, which includes the values 513 and -1,210 seen in the snippet. However, the snippet's other numbers (18, -9, 31) do not match the KB data, and the formatting differs, so not all elements are corroborated.
#
# sentence_87: Tax Rate (%): 28 | - | 8 | - | 14
#  → Keine Evidenz gefunden
#
# sentence_88: Net Income: $-33$ | 337 | 341 | 2,490 | 3,162
#  → Label: Partially Supported
#  → Reason: The KB includes net income values 2,490 and 3,162 (annual results) that match parts of the snippet, but it does not contain -33, 337, or 341, and the snippet's combination of figures is not fully represented in the KB.
#
# sentence_89: Diluted Shares Outstanding: 952 | 1,064 | 1,120 | 1,207 | 1,229
#  → Label: Partially Supported
#  → Reason: The KB includes diluted-weighted-average shares values that match the snippet's trailing figures (1,207 and 1,229) and related per-share calculations, but it does not provide the full five-number sequence (952, 1,064, 1,120, 1,207, 1,229) or explicitly use the term 'diluted shares outstanding' in the same context.
#
# sentence_90: EPS: $-0.03$ | 0.32 | 0.30 | 2.06 | 2.57
#  → Label: Partially Supported
#  → Reason: The KB confirms AMD’s EPS declined and provides some EPS figures from the same earnings deck (e.g., $0.84 in Q4 and $2.57 for FY 2022), which aligns with the last value in the snippet. However, the exact EPS sequence shown in the snippet (-0.03, 0.32, 0.30, 2.06, 2.57) is not present in the KB excerpt, so the snippet is not fully corroborated.
#
# sentence_91: Dividend: - | - | - | - | -
#  → Keine Evidenz gefunden
#
# sentence_92: Revenue Growth Rates: 21.6 | 23.3 | 4.0 | 45.0 | 68.3
#  → Keine Evidenz gefunden
#
# sentence_93: Operating Income Growth: - | 255.1 | 39.9 | 117.0 | 166.5
#  → Keine Evidenz gefunden
#
# sentence_94: Net Income Growth: - | 683.7 | 1.2 | 630.2 | 27.0
#  → Keine Evidenz gefunden
#
# sentence_95: EPS Growth: - | 700.0 | $-6.2$ | 586.7 | 24.8
#  → Keine Evidenz gefunden
#
# sentence_96: Dividend Growth: - | - | - | - | -
#  → Keine Evidenz gefunden
#
# sentence_97: Sustainable Growth Rate: $-15.2$ | 43.3 | 12.7 | 29.1 | 72.1
#  → Keine Evidenz gefunden
#
# sentence_98: Price: High: - | \$34.14 | \$47.31 | \$97.98 | \$164.46
#  → Keine Evidenz gefunden
#
# sentence_99: Price: Low: - | \$9.04 | \$16.94 | \$36.75 | \$72.50
#  → Keine Evidenz gefunden
#
# sentence_100: Price/Sales: High-Low
#  → Keine Evidenz gefunden
#
# sentence_101: nor its content providers are responsible for any damages or losses arising from any use of this information.
#  → Keine Evidenz gefunden
#
# sentence_102: Past performance is no guarantee of future results.
#  → Label: Supported
#  → Reason: The Knowledge Base contains an explicit statement that 'The past performance of our common stock is no indication of future performance,' which aligns with the snippet 'Past performance is no guarantee of future results.'
#
# sentence_103: This data is set forth herein for historical reference only and is not necessarily used in Argus' analysis of the stock set forth on this page of this report or any other stock or other security.
#  → Keine Evidenz gefunden
#
# sentence_104: All earnings figures are in GAAP.
#  → Keine Evidenz gefunden
#
# sentence_105: # A DARQUS ## ADVANCED MICRO DEVICES INC ## Analyst's Notes...Continued
#  → Label: Partially Supported
#  → Reason: KB confirms the document is AMD Q4 2022 earnings call with analysts; this aligns with an Analyst's Notes context, but it does not explicitly verify the specific heading text ('A DARQUS', 'Analyst's Notes...Continued').
#
# sentence_106: She is well respected in financial circles, and we believe she will benefit the already strong leadership team at AMD.
#  → Label: Partially Supported
#  → Reason: KB confirms CFO experience and that she would be an excellent addition to AMD's leadership team, supporting the benefit claim. However, it does not mention or confirm that she is 'well respected in financial circles'.
#
# sentence_107: Overall, and despite challenges that were growing as the fourth quarter progressed, the CEO called 2022 a strong year for AMD.
#  → Label: Supported
#  → Reason: Knowledge Base contains multiple quotes from AMD leadership stating that 2022 was a strong year for AMD despite challenges such as a weak PC environment in the second half, including explicit statements like '2022 was a strong year for AMD' and references to record revenue and growth.
#
# sentence_108: The company transformed the company and accelerated the data center business with new products and the acquisitions of Xilinx and Pensando.
#  → Label: Supported
#  → Reason: KB confirms AMD accelerated its data center momentum and completed the acquisitions of Xilinx and Pensando, including new DPUs/software stack aligned with the snippet.
#
# sentence_109: Data Center and Embedded product sales reached a combined $10.6 billion in 2022, up from $3.9 billion in 2021.
#  → Label: Supported
#  → Reason: KB provides Data Center ($6.043B) and Embedded ($4.552B) 2022 revenues totaling about $10.595B (~$10.6B) and 2021 revenues (Data Center ~$3.694B, Embedded ~$0.246B) totaling ~$3.94B (~$3.9B). An earnings call explicitly states the 2021→2022 rise from $3.9B to $10.6B, aligning with the snippet.
#
# sentence_110: For 4Q22, Data Center revenue of $1.66 billion (30% of total) was up 42% year-over-year and was up 3% sequentially.
#  → Label: Partially Supported
#  → Reason: KB confirms Q4'22 Data Center revenue of $1.655B (~$1.66B) and ~42% YoY growth, and that Data Center revenue was about 30% of total. However, the KB does not provide explicit evidence of a 3% sequential (QoQ) increase for Data Center in Q4'22, so the sequential part is not supported by the provided KB.
#
# sentence_111: Data Center operating profit of $444 million rose 20% from a year earlier, although segment margin tightened to 26.8% in 4Q22 from 31.7% for 4Q21, on mix and higher costs.
#  → Label: Supported
#  → Reason: KB shows Q4'22 Data Center Operating Income of $444m vs $369m in Q4'21 (up ~20%), with Data Center Net Revenue of $1,655m vs $1,163m. These figures imply margins of approximately 26.8% (444/1655) vs 31.7% (369/1163), aligning with the snippet's margin details.
#
# sentence_112: Under the new re-organization following the Xilinx acquisition, Data Center primarily includes EPYC server CPUs, GPUs, data processing units (DPUs) and FPGAs and SoCs that largely came from Xilinx.
#  → Label: Partially Supported
#  → Reason: KB confirms that Data Center includes CPUs, GPUs, DPUs, FPGAs and Adaptive SoC products and notes the Xilinx acquisition, which aligns with the snippet's general idea. However, it does not explicitly mention EPYC branding or that the SoCs largely originated from Xilinx, so the specific details are not fully supported.
#
# sentence_113: Data Center growth in 4Q22 was led by EPYC microprocessor sales, with significant demand growth across cloud customers.
#  → Label: Supported
#  → Reason: The KB states 4Q22 Data Center revenue rose 42% YoY to $1.7B, led by increased adoption of EPYC processors by cloud providers, and notes cloud/hyperscaler demand—matching the claim that Data Center growth was led by EPYC microprocessor sales with significant cloud customer demand.
#
# sentence_114: Cloud sales to North American customers more than doubled year over year as hyperscale customers continue moving their internal workload and external instances to EPYC processors.
#  → Label: Supported
#  → Reason: KB contains the exact statement that cloud sales to North American hyperscalers more than doubled year-over-year as hyperscale customers migrated more workloads to EPYC processors.
#
# sentence_115: Also in Data Center, enterprise revenue declined year-over-year as demand slowed in a worsening macro-environment.
#  → Label: Partially Supported
#  → Reason: The KB confirms Enterprise revenue declined year-over-year due to a slowdown in demand from a macro environment, which matches part of the snippet. However, it does not mention the Data Center segment, so the claim about Data Center is not supported by the KB.
#
# sentence_116: Despite these challenges, AMD continued expanding its pipeline by closing several new wins in 4Q22 with Fortune 500 companies in financial services, technology, energy, aerospace, and other verticals.
#  → Label: Supported
#  → Reason: KB confirms AMD closed several new Fortune 500 wins in Q4 across financial services, automotive, technology, energy and aerospace, aligning with the snippet's claim about Fortune 500 wins in these verticals and the broader ‘other verticals’ phrasing.
#
# sentence_117: EPYC is also winning sockets in high-performance computing (HPC).
#  → Label: Supported
#  → Reason: KB evidence indicates growing EPYC processor adoption in HPC, evidenced by AMD-powered supercomputers in the latest deployments; this aligns with the claim that EPYC is winning sockets in HPC, though the exact word 'sockets' isn’t explicit in the excerpt.
#
# sentence_118: AMD now powers more than 100 of the world's fastest supercomputers, according to the CEO, including 15 of the 20 most energy-efficient.
#  → Label: Supported
#  → Reason: KB states AMD powers 101 (more than 100) of the world's fastest supercomputers and 15 of the top-20 most energy-efficient, aligning with the snippet's numbers. The exact attribution 'according to the CEO' is not explicitly evidenced, but there is no contradiction and the numeric claims are supported.
#
# sentence_119: supercomputers.
#  → Keine Evidenz gefunden
#
# sentence_120: In November, AMD introduced its fourth-generation EPYC processor family, delivering twice the performance with an 80% energy-efficiency boost compared to prior iterations.
#  → Label: Supported
#  → Reason: KB states AMD launched its fourth-generation EPYC processors in November and that they deliver up to 2x faster performance and up to 80% more energy-efficient operation, aligning with the snippet's claims (though the KB compares to competing offerings rather than prior generations).
#
# sentence_121: Customer response has been positive, though likely tempered by the current environment.
#  → Keine Evidenz gefunden
#
# sentence_122: Also for 4Q22, Client revenue of $903 million (16% of total) declined 51% annually and 12% sequentially.
#  → Label: Partially Supported
#  → Reason: KB confirms Client revenue was $903 million and declined 51% year-over-year. It does not provide the 16% of total share or the 12% sequential decline figures; those elements are not supported by the KB excerpts.
#
# sentence_123: Client posted an operating loss of $152 million for 4Q22, down from a profit of $530 million a year earlier; the Client business was also unprofitable in sequentially adjacent 3Q22.
#  → Label: Partially Supported
#  → Reason: KB confirms 4Q22 Client operating loss of $152 million and prior-year 4Q21 operating income of $530 million. However, there is no information in the provided KB about 3Q22 results, so the claim that 3Q22 was unprofitable is not supported by the given evidence.
#
# sentence_124: Client includes CPUs, accelerated processing units (APUs) that integrate microprocessors with graphics processors, and chipsets for desktop and notebook PCs.
#  → Label: Supported
#  → Reason: KB consistently defines the Client segment as including CPUs, APUs (APUs integrate microprocessors with graphics processors/GPUs), and chipsets for desktop and notebook personal computers, which matches the snippet’s phrasing (desktop and notebook PCs).
#
# sentence_125: While demand weakness was most intense in consumer channels, the entire PC space has slowed dramatically.
#  → Keine Evidenz gefunden
#
# sentence_126: According to IDC, worldwide PC unit sales declined 29% in 4Q22 on top of a 15% decline in 3Q22.
#  → Keine Evidenz gefunden
#
# sentence_127: The consumer and notebook distribution channel remains cautious, and the CEO noted that AMD continued to ship units below actual PC consumption in the fourth quarter.
#  → Label: Partially Supported
#  → Reason: KB confirms AMD shipped below PC consumption in Q4 and was reducing downstream inventory, aligning with part of the snippet. It does not explicitly state that the consumer/notebook distribution channel remained cautious, so that portion is not directly supported.
#
# sentence_128: In this way, AMD is helping channel partners further reduce inventory.
#  → Label: Partially Supported
#  → Reason: The KB evidence mentions 'further reducing downstream inventory' and notes increased desktop channel sell-through, which aligns with reducing channel inventory. However, it does not explicitly state that AMD is helping channel partners directly or detailing how such assistance is provided.
#
# sentence_129: At the same time, AMD has delivered multiple new products
#  → Keine Evidenz gefunden
#
# sentence_130: Peer & Industry Analysis
#  → Keine Evidenz gefunden
#
# sentence_131: The graphics in this section are designed to allow investors to compare AMD versus its industry peers, the broader sector, and the market as a whole, as defined by the Argus Universe of Coverage.
#  → Keine Evidenz gefunden
#
# sentence_132: The scatterplot shows how AMD stacks up versus its peers on two key characteristics: long-term growth and value.
#  → Keine Evidenz gefunden
#
# sentence_133: The table builds on the scatterplot by displaying more financial information.
#  → Keine Evidenz gefunden
#
# sentence_134: The bar charts on the right take the analysis two steps further, by broadening
#  → Keine Evidenz gefunden
#
# sentence_135: the comparison groups into the sector level and the market as a whole.
#  → Keine Evidenz gefunden
#
# sentence_136: This tool is designed to help investors understand how AMD might fit into or modify a diversified portfolio.
#  → Keine Evidenz gefunden
#
# sentence_137: TXN: Texas Instruments Inc. | 160,552 | 10.0 | 19.6 | 43.7 | 12.0 | BUY
#  → Label: No Evidence
#  → Reason: The knowledge base excerpts refer to Advanced Micro Devices (AMD) and discuss stock volatility in general; they do not mention Texas Instruments (TXN) or the provided BUY recommendation for TXN.
#
# sentence_138: AMD: Advanced Micro Devices Inc. | 121,169 | 15.0 | 21.5 | 5.6 | 46.1 | BUY
#  → Label: Not Supported
#  → Reason: The Knowledge Base only contains AMD stock repurchase program details from the 2022 Form 10-K/10-Q and related notes; it does not mention any rating of BUY or the specific numeric fields shown in the snippet. Therefore, the snippet's BUY recommendation and figures are not supported by the KB.
#
# sentence_139: INTC: Intel Corp. | 116,912 | 9.0 | 39.3 | 12.7 | 168.1 | BUY
#  → Label: No Evidence
#  → Reason: The knowledge base discusses Intel in the context of AMD filings and market leadership but provides no INTC-specific metrics, ratings, or the BUY recommendation shown in the snippet.
#
# sentence_140: AMAT: Applied Materials Inc. | 93,995 | 11.0 | 12.7 | 25.3 | 6.4 | BUY
#  → Label: No Evidence
#  → Reason: The Knowledge Base discusses AMD (Advanced Micro Devices) in Form 10-Q/10-K filings and contains no information about Applied Materials (AMAT) or a BUY rating for AMAT.
#
# sentence_141: ADI: Analog Devices Inc. | 87,329 | 12.0 | 15.5 | 22.9 | 13.2 | BUY
#  → Label: No Evidence
#  → Reason: The knowledge base mentions Analog Devices (ADI) in litigation and AMD-related context, but provides no stock rating, price metrics, or buy recommendation for Analog Devices Inc. The specific '87,329 | 12.0 | 15.5 | 22.9 | 13.2 | BUY' line is not present or supported by the KB.
#
# sentence_142: LRCX: Lam Research Corp. | 67,482 | 11.0 | 13.8 | 26.9 | 5.3 | BUY
#  → Keine Evidenz gefunden
#
# sentence_143: KLAC: KLA Corp. | 54,351 | 11.0 | 14.6 | 33.8 | 5.8 | BUY
#  → Keine Evidenz gefunden
#
# sentence_144: NXPI: NXP Semiconductors NV | 47,761 | 13.0 | 12.4 | 21.1 | 14.1 | BUY
#  → Keine Evidenz gefunden
#
# sentence_145: Peer Average: 93,694 | 11.5 | 18.7 | 24.0 | 33.9
#  → Keine Evidenz gefunden
#
# sentence_146: ![img-1.jpeg](img-1.jpeg)
#  → Keine Evidenz gefunden
#
# sentence_147: ![img-2.jpeg](img-2.jpeg)
#  → Keine Evidenz gefunden
#
# sentence_148: # ADVANCED MICRO DEVICES INC ## Analyst's Notes...Continued that the company believes is helping mitigate some of the worst of the downdraft.
#  → Label: No Evidence
#  → Reason: The KB excerpt discusses industry downturns and adverse effects on AMD but contains no mention of analyst notes or any assertion that the company believes it is mitigating the downdraft.
#
# sentence_149: Although overall PC demand remains soft, the CEO noted that 'desktop channel self-through increased sequentially during the holiday season.'
#  → Label: Supported
#  → Reason: The knowledge base includes the same assertion: desktop channel sell-through increased sequentially during the holiday season while overall PC demand remains soft. The snippet’s content aligns with the KB (minor spelling difference 'self-through' vs 'sell-through'), and the context (Q4 2022 AMD earnings call) supports attribution to a senior company representative, though the explicit 'CEO noted' phrasing is not verbatim in the excerpt.
#
# sentence_150: AMD launched its latest-generation Ryzen series notebook processors in January, including the first Ryzen processors to feature AI capabilities.
#  → Label: Supported
#  → Reason: KB evidence explicitly states January launch of the latest-gen Ryzen 7000-series notebook processors (e.g., Ryzen 7040) and identifies them as AMD's first to feature Ryzen AI with an on-chip AI inference engine, aligning with the snippet.
#
# sentence_151: This includes the on-chip AI inference engine built into an x86 processor, in the first integration of AMD and Xilinx intellectual property.
#  → Label: Supported
#  → Reason: Knowledge Base explicitly states on-chip AI inference engine in x86 processors (Ryzen AI) and cites XDNA as the first integration of AMD and Xilinx IP, i.e., the first integration of their IP.
#
# sentence_152: Gaming revenue of $1.64 billion (29% of total) was down 7% year-over-year and up 1% sequentially.
#  → Label: Partially Supported
#  → Reason: KB confirms Gaming revenue of about $1.6B and a 7% YoY decline, but does not verify the exact $1.64B figure, the 29% of total share, or a +1% sequential change.
#
# sentence_153: Gaming operating profit of $269 million was down 35% from the year-earlier holiday quarter, while segment margin of 16.2% in 4Q22 declined from 23.1% for 4Q21.
#  → Label: Supported
#  → Reason: KB shows Gaming operating income of $266M (16% margin) in 4Q22 vs $407M (23% margin) in 4Q21, which aligns with the snippet’s $269M and 16.2% vs 23.1%; the small numeric difference (266 vs 269; 16% vs 16.2%) is due to rounding or reporting variance.
#
# sentence_154: The Gaming segment primarily includes discreet graphics processing units (GPUs) under the Radeon name along with semi-custom SoC products and development services.
#  → Label: Partially Supported
#  → Reason: The Knowledge Base confirms that the Gaming segment primarily includes discrete GPUs, semi-custom SoC products and development services, which matches the core of the snippet. However, it does not explicitly state that these GPUs are specifically branded under the Radeon name, so the branding detail is not evidenced.
#
# sentence_155: In 4Q22, lower gaming graphics sales more than offset higher semi-custom revenue.
#  → Label: Supported
#  → Reason: The Knowledge Base explicitly states that in Q4’22 revenue was $1.6B, down 7% YoY, and that this decline was due to lower gaming graphics revenue being partially offset by higher semi-custom revenue (i.e., semi-custom growth offsetting the drop in gaming graphics).
#
# sentence_156: Despite the maturity of the major gaming consoles including Microsoft Xbox and Sony PS5, semi-custom SoC revenue 'remained strong' in the holiday quarter.
#  → Label: Partially Supported
#  → Reason: KB confirms semi-custom SoC revenue grew YoY due to ongoing strong demand for game consoles during the holidays, which supports the 'remained strong' aspect. However, the KB does not address the maturity of the gaming consoles, so that portion of the snippet is not evidenced.
#
# sentence_157: Although both console families are relatively late in life, console scarcity beginning in the pandemic and stretching through the supply chain crisis appears to have resulted in significant pent-up demand that carried into holiday sales.
#  → Keine Evidenz gefunden
#
# sentence_158: Embedded revenue of $1.40 billion (25% of total) rose from $71 million a year earlier.
#  → Label: Partially Supported
#  → Reason: KB confirms embedded revenue of about $1.4B and a YoY rise from $71M. However, it does not support the claim that embedded revenue equals 25% of total; in the cited figures, embedded revenue is roughly 31% of total (1.397B of 4.552B), not 25%.
#
# sentence_159: Embedded sales were also up 7% sequentially representing organic growth, given that Xilinx has contributed since 2Q22.
#  → Label: Partially Supported
#  → Reason: KB confirms embedded revenue grew due to including Xilinx (driven by Xilinx). It does not document a 7% sequential increase or organic growth, and the framing in KB implies growth from Xilinx inclusion rather than organic growth. Therefore, the snippet is not fully supported and the organic/7% sequential aspects are not substantiated.
#
# sentence_160: Embedded operating profit was $699 million compared to $18 million a year earlier; segment margin was 50.0% in 4Q22 vs. 25.4% for 4Q21.
#  → Label: Supported
#  → Reason: KB states embedded operating income of $699 million and 50% of revenue, vs $18 million and 25% a year ago (4Q22 vs 4Q21). The snippet cites $699 million, $18 million, 50.0% and 25.4%. These figures align, with a minor rounding difference (25% vs 25.4%), which is generally acceptable.
#
# sentence_161: The Embedded segment includes a variety of CPUs, GPUs, FPGAs,
#  → Label: Supported
#  → Reason: KB states Embedded segment primarily includes embedded CPUs, GPUs, FPGAs, and Adaptive SoC products (and sometimes APUs), which aligns with the snippet mentioning CPUs, GPUs, and FPGAs.
#
# sentence_162: Adaptive SoCs, and Adaptive Compute Acceleration Platform (ACAP) products.
#  → Label: Supported
#  → Reason: The knowledge base includes explicit references to Adaptive SoC products and to the Adaptive Compute Acceleration Platform (ACAP) in the Form 10-Q excerpt, and additional 10-K excerpts discuss Adaptive SoCs (e.g., Versal) and related platforms. This directly supports the snippet.
#
# sentence_163: Sales of acquired Xilinx product families are growing because AMD has brought additional manufacturing scales and marketing resources to these products.
#  → Label: No Evidence
#  → Reason: The KB confirms the Xilinx acquisition and expanded product portfolio (FPGAs, adaptive SoC, ACAP) but provides no information on sales growth of Xilinx product families or the impact of manufacturing scale or marketing resources on such growth.
#
# sentence_164: Key categories served, including aerospace-defense, industrial, medical, and semiconductor test & measurement, all grew in the quarter; several categories achieved record sales.
#  → Label: Partially Supported
#  → Reason: KB confirms record sales across embedded markets including aerospace/defense, industrial, and healthcare (medical) and mentions test and emulation, which overlaps with some snippet categories. However, it does not verify that all listed categories grew, nor exactly map 'semiconductor test & measurement' to 'test and emulation.'
#
# sentence_165: AMD recently announced multiple new wins in automotive in areas including ADAS and LiDAR for semi-autonomous driving.
#  → Label: Supported
#  → Reason: KB excerpts describe AMD announcing automotive wins including ADAS-related systems (Automated Parking Assist) and LiDAR platforms (DENSO LiDAR), along with associated sensors (forward camera, 4D Radar), which align with the snippet's claim of ADAS and LiDAR wins for semi-autonomous driving.
#
# sentence_166: In the year since closing Xilinx, according to the CEO, integration has gone extremely well.
#  → Label: Supported
#  → Reason: KB excerpts from AMD's Q4 2022 earnings call reference approaching the one-year anniversary of the Xilinx acquisition and state that 'the integration has gone extremely...' (implying 'extremely well'), which aligns with the snippet stating the CEO said the integration has gone extremely well.
#
# sentence_167: The company believes AMD overall is positioned to grow revenue and gain share in 2023 based on the strength of its competitive positioning and leadership high-performance and adaptive-computing product portfolios.
#  → Label: Supported
#  → Reason: KB includes explicit statements from AMD’s Q4 2022 materials that the company believes it is well-positioned to grow revenue and gain share in 2023 based on its competitive positioning and leadership in high-performance and adaptive (adaptive-computing) product portfolios.
#
# sentence_168: As 2023 gets underway, AMD looks for a strong year despite the weak PC market.
#  → Label: Partially Supported
#  → Reason: KB confirms PC market weakness in 2023 (PC TAM down ~10%) and notes an expectation that the second half will be stronger than the first, indicating a mixed demand environment. It does not explicitly state that AMD will have a 'strong year' in 2023, so the claim is only partially supported by the evidence.
#
# sentence_169: The company looks for a stronger second half than first half, with diversified strength across data center, gaming, and embedded to counter PC weakness until the client bus
#  → Label: Partially Supported
#  → Reason: The KB confirms optimism for a stronger second half and growth in Embedded and Data Center, and notes PC/client bus weakness as a headwind, which aligns with the idea of countering weakness. However, it does not mention the gaming segment, so the claim of diversified strength across data center, gaming, and embedded is not fully evidenced.
#
# sentence_170: EARNINGS & GROWTH ANALYSIS
#  → Keine Evidenz gefunden
#
# sentence_171: For 4Q22, Advanced Micro Devices reported revenue of $6.0 billion, which was up 16% year-over-year and 1% sequentially.
#  → Label: Partially Supported
#  → Reason: KB shows 4Q22 revenue of $5.6B with 16% YoY growth (aligned with snippet's YoY claim), but the snippet states $6.0B and 1% sequential growth. KB provides no evidence of $6.0B or of a 1% sequential increase.
#
# sentence_172: Revenue included a full contribution from Xilinx.
#  → Label: Partially Supported
#  → Reason: Evidence shows AMD’s revenue growth and embedded segment were driven by the inclusion of Xilinx revenue (including post-acquisition embedded revenue and some pre-acquisition Xilinx revenue). However, it does not explicitly state that the revenue included a 'full' contribution from Xilinx for the entire period.
#
# sentence_173: Revenue exceeded the high end of the guidance range of $5.2-$5.8 billion and was nearly half a billion dollars above the consensus estimate of $5.5 billion.
#  → Keine Evidenz gefunden
#
# sentence_174: Non-GAAP gross margin was 51.1% for 4Q22, vs. 49.9% for 3Q22 and 50.3% a year earlier; gross margins gains reflected better mix (fewer consumer PCs).
#  → Label: Partially Supported
#  → Reason: The KB confirms a non-GAAP gross margin for Q4 2022 around 51% and attributes margin gains to a richer mix (higher Embedded/Data Center, lower Client/consumer-PC revenue). This aligns with the snippet’s assertion of margin improvement due to mix. However, the exact figures cited (51.1% for 4Q22, 49.9% for 3Q22, 50.3% a year earlier) are not consistently documented in the KB (the KB lists 51% or 52% for Q4/FY and does not provide a 3Q22 margin), so the numeric specifics are not fully supported. The mix-driven explanation is supported, but the precise numbers are not.
#
# sentence_175: Non-GAAP operating margin was 22.5% for 3Q22, vs. 22.7% for 3Q22 and 27.5% a year earlier.
#  → Label: Partially Supported
#  → Reason: KB shows Non-GAAP operating margin for Q3 2022 as 23% (close to 22.5%), but does not include 22.5% or 22.7% as exact figures; it also shows 27% for the year-ago quarter (not 27.5%). The snippet’s specific numbers do not exactly match the KB data, though they are in the same general range.
#
# sentence_176: Non-GAAP profit totaled $0.69 per diluted share, down 25% from $0.92 a year earlier and up $0.01 sequentially.
#  → Label: Partially Supported
#  → Reason: KB confirms Non-GAAP diluted EPS of $0.69 and a 25% decline vs $0.92 year ago, but provides no evidence of a $0.01 sequential increase.
#
# sentence_177: AMD management does not provide explicit EPS guidance.
#  → Keine Evidenz gefunden
#
# sentence_178: The Street had projected
#  → Keine Evidenz gefunden
#
# sentence_179: non-GAAP EPS of $0.67.
#  → Label: Contradicted
#  → Reason: KB states non-GAAP diluted EPS of $0.69 for the quarter, not $0.67; the snippet’s figure is not supported by the KB evidence.
#
# sentence_180: For 2022, revenue of $23.6 billion rose 44% from $16.4 billion for 2021.
#  → Label: Supported
#  → Reason: KB shows AMD 2022 revenue of $23.6B, up 44% year-over-year from $16.4B in 2021, matching the snippet.
#
# sentence_181: And non-GAAP EPS of $3.54 was up 26% from $2.81 a year earlier.
#  → Label: Partially Supported
#  → Reason: KB shows non-GAAP EPS of $3.50 (FY 2022) vs $2.79, up 25%, while the snippet states $3.54 up 26% from $2.81. The directional trend is consistent, but the exact figures differ, so it is not fully supported.
#
# sentence_182: For 1Q23, AMD guided for revenue of $5.0-$5.6 billion, which at the $5.3 billion midpoint would be down 10% annually and 5% from 4Q22.
#  → Label: Supported
# ...
#
# sentence_216: Saeied Moshkelani is SVP and GM of Client Compute Group.
#  → Keine Evidenz gefunden
#
# sentence_217: We believe that the company's IP monetization strategy, as well as success in EE&SC, could give CEO Su a longer leash than was given to prior CEOs.
#  → Keine Evidenz gefunden
#
# sentence_218: The pandemic has turned around what had been structural decline in PCs, and AMD appears positioned for market share gains at the expense of Intel, which is wrestling with production issues.
#  → Keine Evidenz gefunden
#
# sentence_219: The acquisition of Xilinx for $\$ 35$ billion carries multiple risks, including potential issues with cultural integration, a misreading of end-market outlooks, and potential end-market cannibalization.
#  → Keine Evidenz gefunden
#
# sentence_220: We believe these risks are worth the TAM opportunities afforded by XLNX.
#  → Keine Evidenz gefunden
#
# sentence_221: The all-stock nature of the deal also eliminates the potential for a cumbersome debt burden.
#  → Keine Evidenz gefunden
#
# sentence_222: The deal has diluted the share base, but AMD is acquiring growing and higher-margin assets that should not be dilutive to EPS.
#  → Keine Evidenz gefunden
#
# sentence_223: A main risk for AMD, as for other semiconductor companies, is the possibility of a general economic downturn and a corresponding dip in technology hardware sales due to inflation and rising interest rates.
#  → Keine Evidenz gefunden
#
# sentence_224: We believe that AMD has the financial strength, market leadership, and growth characteristics to weather this storm and emerge a stronger player.
#  → Keine Evidenz gefunden
#
# sentence_225: We also believe the percentage of hours worked away from the office will continue to increase.
#  → Keine Evidenz gefunden
#
# sentence_226: That should drive long-term demand for personal PCs served by AMD CPUs, for data center CPUs to manage fast-growing data traffic, and for GPUs for gaming applications.
#  → Label: Partially Supported
#  → Reason: The KB confirms AMD's focus on desktop/notebook CPUs, GPUs (for gaming), and data center solutions, which aligns with the markets mentioned in the snippet. However, it does not explicitly state that there will be long-term demand driven by these factors; the document is a financial results report, not a direct assertion of future demand drivers.
#
# sentence_227: AMD has been betting heavily on nontraditional businesses, including embedded, micro-server, and semi-custom (gaming console).
#  → Label: Partially Supported
#  → Reason: KB confirms embedded as a major growth driver and discusses diversification and synergies (e.g., with Xilinx), which aligns with part of the snippet. However, it does not explicitly mention micro-server or semi-custom (gaming consoles), nor does it clearly state that AMD is 'betting heavily' on nontraditional businesses. Therefore, the overall claim is not fully supported.
#
# sentence_228: Simultaneously, AMD is supporting both stand-alone CPU and
#  → Keine Evidenz gefunden
#
# sentence_229: GPU lines as well as its APU line that combines compute and graphics processing on a single die.
#  → Keine Evidenz gefunden
#
# sentence_230: COMPANY DESCRIPTION
#  → Keine Evidenz gefunden
#
# sentence_231: Advanced Micro Devices is the number-two player in x86-based microprocessors, behind Intel, and -- with the 2008 acquisition of ATI -- a top player in graphic processors.
#  → Label: Not Supported
#  → Reason: The KB states Intel is the market share leader and that AMD competes in x86 CPUs and graphics-related markets, but it does not explicitly say AMD is the number-two in x86-based microprocessors, nor does it reference the 2008 ATI acquisition or AMD being a top graphics processor player.
#
# sentence_232: In 2021, Advanced Micro Devices acquired Xilinx, expanding its presence in embedded computing and data center.
#  → Label: Partially Supported
#  → Reason: The KB confirms AMD completed the Xilinx acquisition in February 2022 and that it expands the product portfolio (FPGA/adaptive computing) with Embedded and Data Center impact. However, the snippet states the acquisition occurred in 2021, which is not supported by the KB.
#
# sentence_233: VALUATION
#  → Keine Evidenz gefunden
#
# sentence_234: AMD shares are trading at 21.5 -times our 2023 non-GAAP EPS estimate and at 14.7 -times our 2024 projection.
#  → Label: No Evidence
#  → Reason: The KB document covers AMD's 2022 results and 2022 non-GAAP EPS, but provides no 2023 non-GAAP EPS estimates or 2024 projections; thus it does not support the stated forward-looking multiples.
#
# sentence_235: AMD trades at a two-year forward P/E of 18.1, compared to a multiple of 42.6 for the 2018-2021 period.
#  → Label: No Evidence
#  → Reason: The KB excerpts discuss AMD's 2022 financial performance, Form 10-K details, and currency hedges but do not mention forward P/E ratios or any P/E multiples (2-year forward P/E 18.1 or 2018-2021 period 42.6). Therefore cannot support the snippet.
#
# sentence_236: The two-year-forward relative P/E of 1.05 is just above the market P/E and remains well below the historical average for 2018-2021 of 2.19.
#  → Keine Evidenz gefunden
#
# sentence_237: Historical comparable valuation for AMD indicates value in the low \$ 200$ s, in a stable trend and well above current prices.
#  → Keine Evidenz gefunden
#
# sentence_238: Peer group analysis suggests that AMD deserves to trade at a premium to peers on absolute and relative P/E; our peer-indicated value is in the \$ 90$ s, down from a late 2021 peak in the \$ 160$ s due to the 2022 peer-group selloff.
#  → Keine Evidenz gefunden
#
# sentence_239: Our discounted free cash flow model renders a fair value in the \$ 150$ s, down from past peaks on slowing PC momentum.
#  → Keine Evidenz gefunden
#
# sentence_240: Blending these approaches, we arrive at a value above \$ 150$, below past peaks but well above current prices.
#  → Keine Evidenz gefunden
#
# sentence_241: While the client market is likely to remain volatile in the near term, we are encouraged by the progress of EPYC in cloud and enterprise data center, the success of Ryzen CPUs for desktop and notebook PCs, and the outlook for AMD's Radeon GPUs in the PC gaming.
#  → Label: Partially Supported
#  → Reason: KB references Radeon GPU activity with strong demand (Radeon RX, 7900) and mentions growth in the Data Center, which could align with EPYC/data-center progress and GPU outlook. However, it does not explicitly address EPYC progress, Ryzen desktop/notebook success, or a near-term volatile client market forecast, and it contains indications of a weak PC market and potential declines in Client/Gaming, which complicates direct support for the snippet as written.
#
# sentence_242: We regard the XLNX deal as a logical next step in AMD's journey, one that adds
#  → Keine Evidenz gefunden
#
# sentence_243: high-growth complementary assets that will accelerate AMD's growth in the cloud data center and high-value-added nontechnology markets.
#  → Keine Evidenz gefunden
#
# sentence_244: Like many Technology stocks, AMD has slipped from its highs on consumer demand softness.
#  → Label: Partially Supported
#  → Reason: KB confirms soft consumer demand affecting AMD (lower unit shipments and gaming graphics sales), aligning with the 'consumer demand softness' aspect. It does not explicitly state AMD slipped from its highs or compare to peers, so not fully supported.
#
# sentence_245: Current prices in our view do not fully reflect AMD's revenue and margin growth potential, and ongoing market share gains at Intel's expense.
#  → Keine Evidenz gefunden
#
# sentence_246: We are reiterating our BUY rating to a 12-month target price of $100.
#  → Keine Evidenz gefunden
#
# sentence_247: On February 1 at midday, BUY-rated AMD traded at $80.48, up $5.33.
#  → Keine Evidenz gefunden
#
# sentence_248: Argus Research, founded by Economist Harold Dorsey in 1934, has built a top-down, fundamental system that is used by Argus analysts.
#  → Keine Evidenz gefunden
#
# sentence_249: This six-point system includes Industry Analysis, Growth Analysis, Financial Strength Analysis, Management Assessment, Risk Analysis and Valuation Analysis.
#  → Keine Evidenz gefunden
#
# sentence_250: Utilizing forecasts from Argus' Economist, the Industry Analysis identifies industries expected to perform well over the next one-to-two years.
#  → Keine Evidenz gefunden
#
# sentence_251: The Growth Analysis generates proprietary estimates for companies under coverage.
#  → Keine Evidenz gefunden
#
# sentence_252: In the Financial Strength Analysis, analysts study ratios to understand profitability, liquidity and capital structure.
#  → Keine Evidenz gefunden
#
# sentence_253: During the Management Assessment, analysts meet with and familiarize themselves with the processes of corporate management teams.
#  → Keine Evidenz gefunden
#
# sentence_254: Quantitative trends and qualitative threats are assessed under the Risk Analysis.
#  → Keine Evidenz gefunden
#
# sentence_255: And finally, Argus' Valuation Analysis model integrates a historical ratio matrix, discounted cash flow modeling, and peer comparison.
#  → Keine Evidenz gefunden
#
# sentence_256: THE ARGUS RESEARCH RATING SYSTEM
#  → Keine Evidenz gefunden
#
# sentence_257: Argus uses three ratings for stocks: BUY, HOLD, and SELL.
#  → Keine Evidenz gefunden
#
# sentence_258: Stocks are rated relative to a benchmark, the S&P 500.
#  → Keine Evidenz gefunden
#
# sentence_259: To make this determination, Argus Analysts set target prices, use beta as the measure of risk, and compare expected risk-adjusted stock returns to the S&P 500 forecasts set by the Argus Market Strategist.
#  → Keine Evidenz gefunden
#
# sentence_260: A HOLD-rated stock is expected to perform in line with the S&P 500.
#  → Keine Evidenz gefunden
#
# sentence_261: A SELL-rated stock is expected to underperform the S&P 500.
#  → Keine Evidenz gefunden
#
# sentence_262: Argus Research Disclaimer
#  → Keine Evidenz gefunden
#
# sentence_263: Argus Research Co. (ARC) is an independent investment research provider whose parent company, Argus Investors' Counsel, Inc. (AIC), is registered with the U.S. Securities and Exchange Commission.
#  → Keine Evidenz gefunden
#
# sentence_264: Argus Investors' Counsel is a subsidiary of The Argus Research Group, Inc.
#  → Keine Evidenz gefunden
#
# sentence_265: Neither The Argus Research Group nor any affiliate is a member of the FINRA or the SIPC.
#  → Keine Evidenz gefunden
#
# sentence_266: Argus Research is not a
#  → Keine Evidenz gefunden
#
# sentence_267: Registered broker dealer and does not have investment banking operations.
#  → Keine Evidenz gefunden
#
# sentence_268: The Argus trademark, service mark and logo are the intellectual property of The Argus Research Group, Inc.
#  → Keine Evidenz gefunden
#
# sentence_269: The information contained in this research report is produced and copyrighted by Argus Research Co., and any unauthorized use, duplication, redistribution or disclosure is prohibited by law and can result in prosecution.
#  → Keine Evidenz gefunden
#
# sentence_270: The content of this report may be derived from Argus research reports, notes, or analyses.
#  → Keine Evidenz gefunden
#
# sentence_271: The opinions and information contained herein have been obtained or derived from sources believed to be reliable, but Argus makes no representation as to their timeliness, accuracy or completeness or for their fitness for any particular purpose.
#  → Keine Evidenz gefunden
#
# sentence_272: In addition, this content is not prepared subject to Canadian disclosure requirements.
#  → Keine Evidenz gefunden
#
# sentence_273: This report is not an offer to sell or a solicitation of an offer to buy any security.
#  → Keine Evidenz gefunden
#
# sentence_274: The information and material presented in this report are for general information only and do not specifically address individual investment objectives, financial situations or the particular needs of any specific person who may receive this report.
#  → Keine Evidenz gefunden
#
# sentence_275: Investing in any security or investment strategies discussed may not be suitable for you and it is recommended that you consult an independent investment advisor.
#  → Keine Evidenz gefunden
#
# sentence_276: Nothing in this report constitutes individual investment, legal or tax advice.
#  → Keine Evidenz gefunden
#
# sentence_277: Argus may issue or may have issued other reports that are inconsistent with or may reach different conclusions than those represented in this report, and all opinions are reflective of judgments made on the original date of publication.
#  → Keine Evidenz gefunden
#
# sentence_278: Argus is under no obligation to ensure that other reports are brought to the attention of any recipient of this report.
#  → Keine Evidenz gefunden
#
# sentence_279: Argus shall accept no liability for any loss arising from the use of this report, nor shall Argus treat all recipients of this report as customers simply by
#  → Keine Evidenz gefunden
#
# sentence_280: virtue of their receipt of this material.
#  → Keine Evidenz gefunden
#
# sentence_281: Investments involve risk and an investor may incur either profits or losses.
#  → Keine Evidenz gefunden
#
# sentence_282: Past performance should not be taken as an indication or guarantee of future performance.
#  → Label: Supported
#  → Reason: The knowledge base includes an explicit statement that past performance of our common stock is no indication of future performance, which aligns with the snippet’s message that past performance should not be taken as an indication or guarantee of future performance.
#
# sentence_283: Argus has provided independent research since 1934.
#  → Keine Evidenz gefunden
#
# sentence_284: Argus officers, employees, agents and/or affiliates may have positions in stocks discussed in this report.
#  → Keine Evidenz gefunden
#
# sentence_285: No Argus officers, employees, agents and/or affiliates may serve as officers or directors of covered companies, or may own more than one percent of a covered company's stock.
#  → Keine Evidenz gefunden
#
# sentence_286: Argus Investors' Counsel (AIC), a portfolio management business based in Stamford, Connecticut, is a customer of Argus Research Co.
#  → Keine Evidenz gefunden
#
# sentence_287: (ARC), based in New York.
#  → Keine Evidenz gefunden
#
# sentence_288: Argus Investors' Counsel pays Argus Research Co. for research used in the management of the AIC core equity strategy and model portfolio and UIT products, and has the same access to Argus Research Co. reports as other customers.
#  → Keine Evidenz gefunden
#
# sentence_289: However, clients and prospective clients should note that Argus Investors' Counsel and Argus Research Co., as units of The Argus Research Group, have certain employees in common, including those with both research and portfolio management responsibilities, and that Argus Research Co. employees participate in the management and marketing of the AIC core equity strategy and UIT and model portfolio products.
#  → Keine Evidenz gefunden
#
# sentence_290: ## Morningstar Disclaimer (c) 2023 Morningstar, Inc.
#  → Keine Evidenz gefunden
#
# sentence_291: All Rights Reserved.
#  → Keine Evidenz gefunden
#
# sentence_292: Certain financial information included in this report: (1) is proprietary to Morningstar and/or its content providers; (2) may not be copied or distributed; and (3) is not warranted to be accurate, complete or timely.
#  → Keine Evidenz gefunden
#
# sentence_293: Neither Morningstar nor its content providers are responsible for any damages or losses arising from any use of this information.
#  → Keine Evidenz gefunden
#
# sentence_294: Past performance is no guarantee of future results.
#  → Label: Supported
#  → Reason: The KB states that 'the past performance of our common stock is no indication of future performance,' which conveys the same caution as 'Past performance is no guarantee of future results.' The wording differs slightly, but the underlying concept aligns.
#
# Fertig, Bewertungen in evaluations.json gespeichert

# %% [markdown]
# # Evaluation

# %%
# Ready to run notebook cell that reads your two files
# and builds all requested overviews, including cross tables

# Configure file paths here
EVAL_PATH = "evaluations.json"
ROSENBLATT_PATH = "02_01_2023_Rosenblatt_Export.json"

import json
import pandas as pd
from pathlib import Path

# ---------- load evaluations.json ----------
with open(Path(EVAL_PATH), "r", encoding="utf-8") as f:
    evaluations = json.load(f)

# evaluations.json is expected to be a dict keyed by sentence ids
eval_rows = []
for sid, payload in evaluations.items():
    eval_rows.append({
        "sentence_id": sid,
        "evaluation": payload.get("evaluation", ""),
        "reason": payload.get("reason", "")
    })
df_eval = pd.DataFrame(eval_rows).sort_values("sentence_id").reset_index(drop=True)

# counts of evaluation categories with fixed buckets
all_eval_categories = ["Supported", "Partially Supported", "Not Supported", "Contradicted", "No Evidence"]
eval_counts_actual = (
    df_eval["evaluation"]
    .value_counts(dropna=False)
    .rename_axis("evaluation")
    .reset_index(name="count")
)
eval_counts = (
    pd.DataFrame({"evaluation": all_eval_categories})
    .merge(eval_counts_actual, on="evaluation", how="left")
    .fillna({"count": 0})
    .astype({"count": int})
)

# ---------- load 02_01_2023_Rosenblatt_Export.json ----------
with open(Path(ROSENBLATT_PATH), "r", encoding="utf-8") as f:
    rosenblatt = json.load(f)

items = rosenblatt.get("items", [])
df_items = pd.DataFrame(items) if items else pd.DataFrame(columns=["text","quote","types","source","chunk_id","page"])
df_items = df_items.reset_index(drop=True)

# source overview for text other table with fixed buckets
all_sources = ["text", "other", "table"]
if not df_items.empty and "source" in df_items:
    source_counts_actual = (
        df_items["source"].value_counts(dropna=False)
        .rename_axis("source")
        .reset_index(name="count")
    )
else:
    source_counts_actual = pd.DataFrame(columns=["source","count"])
source_counts = (
    pd.DataFrame({"source": all_sources})
    .merge(source_counts_actual, on="source", how="left")
    .fillna({"count": 0})
    .astype({"count": int})
)

# type overview Statement Evaluation Forcast with fixed buckets
if not df_items.empty and "types" in df_items:
    df_types_long = df_items.explode("types")
else:
    df_types_long = pd.DataFrame(columns=["types"])
all_types = ["Statement", "Evaluation", "Forcast"]  # keep exact label
if not df_types_long.empty and "types" in df_types_long:
    type_counts_actual = (
        df_types_long["types"].value_counts(dropna=False)
        .rename_axis("type")
        .reset_index(name="count")
    )
else:
    type_counts_actual = pd.DataFrame(columns=["type","count"])
type_counts = (
    pd.DataFrame({"type": all_types})
    .merge(type_counts_actual, on="type", how="left")
    .fillna({"count": 0})
    .astype({"count": int})
)

# ---------- cross overviews: evaluation x source and evaluation x type ----------
# align evaluations with items by order: sentence_1 -> items[0], etc
# if lengths mismatch, align by the min length
min_len = min(len(df_eval), len(df_items))
if min_len > 0:
    df_merge = pd.concat(
        [
            df_eval.loc[:min_len - 1, ["sentence_id", "evaluation"]].reset_index(drop=True),
            df_items.loc[:min_len - 1, ["source", "types"]].reset_index(drop=True)
        ],
        axis=1
    )
    df_merge = df_merge.explode("types")
else:
    df_merge = pd.DataFrame(columns=["sentence_id","evaluation","source","types"])

# ensure categories are present even if zero by reindexing after crosstab
def ensure_crosstab_buckets(ct, index_labels, column_labels):
    # add missing index
    for lab in index_labels:
        if lab not in ct.index:
            ct.loc[lab] = 0
    # add missing columns
    for lab in column_labels:
        if lab not in ct.columns:
            ct[lab] = 0
    # sort to fixed order
    ct = ct.reindex(index=index_labels)
    ct = ct.reindex(columns=column_labels)
    return ct.astype(int)

# evaluation x source
if not df_merge.empty:
    eval_by_source = pd.crosstab(df_merge["evaluation"], df_merge["source"])
else:
    eval_by_source = pd.DataFrame()

eval_by_source = ensure_crosstab_buckets(
    eval_by_source, all_eval_categories, all_sources
)

# evaluation x type
if not df_merge.empty:
    eval_by_type = pd.crosstab(df_merge["evaluation"], df_merge["types"])
else:
    eval_by_type = pd.DataFrame()

eval_by_type = ensure_crosstab_buckets(
    eval_by_type, all_eval_categories, all_types
)

# ---------- display ----------
print("Evaluation counts")
display(eval_counts)

print("Source counts")
display(source_counts)

print("Type counts")
display(type_counts)

print("Evaluation x Source")
display(eval_by_source)

print("Evaluation x Type")
display(eval_by_type)
# Out:
# Evaluation counts
#             evaluation  count
# 0            Supported     42
# 1  Partially Supported     54
# 2        Not Supported      9
# 3         Contradicted      3
# 4          No Evidence    139
# Source counts
#   source  count
# 0   text    213
# 1  other     25
# 2  table     56
# Type counts
#          type  count
# 0   Statement    265
# 1  Evaluation     16
# 2     Forcast      0
# Evaluation x Source
# source               text  other  table
# evaluation
# Supported              31      4      7
# Partially Supported    38      4     15
# Not Supported           6      1      2
# Contradicted            2      0      1
# No Evidence           110      9     31
# Evaluation x Type
# types                Statement  Evaluation  Forcast
# evaluation
# Supported                   34           2        0
# Partially Supported         53           3        0
# Not Supported                7           0        0
# Contradicted                 2           0        0
# No Evidence                122          11        0
